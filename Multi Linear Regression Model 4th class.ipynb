# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
df = pd.read_csv("/content/Vehicle_Maintenance_Cost_Dataset_1000 (1).csv")
df.head()
# Out:
#    Vehicle_ID   Brand  Vehicle_Age  Mileage  Engine_Size_CC Fuel_Type  \
# 0           1     BMW            4    11556            2000    Petrol
# 1           2  Toyota            3    62314            1800    Diesel
# 2           3     Kia            9   217187            1000    Hybrid
# 3           4    Ford            4    29312            3000    Hybrid
# 4           5    Ford           13    25656            2000    Diesel
#
#   Transmission  Service_Count  Previous_Repair_Cost  Usage_Type  \
# 0    Automatic              7                  1828  Commercial
# 1       Manual             16                  4931    Personal
# 2       Manual              5                  5719    Personal
# 3    Automatic              3                  2940  Commercial
# 4    Automatic             20                  5066    Personal
#
#   Driving_Condition  Maintenance_Cost
# 0              City           4157.34
# 1           Highway           7773.21
# 2              City           8891.31
# ...

# %%
lr = linear_model.LinearRegression()
lr.fit(df[['Vehicle_Age', 'Mileage', 'Service_Count', 'Previous_Repair_Cost']],df.)
# Out:
# LinearRegression()

# %%
# Out:
#    Vehicle_Age  Mileage  Service_Count  Previous_Repair_Cost
# 0            5    50000             10                  2500

# %%
predicted_cost = lr.predict([[5,50000,10,2500]])
print(round(predicted_cost[0]),"Rs")
# Out:
# 5750 Rs
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
